# %% [markdown]
# <a href="https://colab.research.google.com/github/XiaoYu1114/neurosynth/blob/master/IntroToKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Keras
#
# #### OHBM 2018 Educational Course
#
# Anisha Keshavan
#
#
# University of Washington
#
#
# **Contact**: email: [anishakeshavan@gmail.com](mailto:anishakeshavan@gmail.com) , Twitter: [@akeshavan\_](https://twitter.com/akeshavan_)

# %% [markdown]
# ## Set Up:

# %% [markdown]
# 3 ways to set up:
#
# 1. If you have a Python environment set up on your computer:
#
#         git clone https://github.com/brainhack101/IntroDL
#         cd IntroDL
#         pip install -r requirements.txt
#         jupyter notebook
#
# 2. Go to https://notebooks.azure.com/akeshavan0/libraries/IntroDL , sign in, and click `clone`
#
# 3. Go to colaboratory: https://colab.research.google.com/github/akeshavan/IntroDL/blob/master/IntroToKeras.ipynb and sign in. Try to get a GPU runtime:
#
# ![](https://github.com/akeshavan/IntroDL/blob/master/colabInstructions.png?raw=1)
#
# ### How to use this notebook
#
# * Hit Shift + Enter on your keyboard to run each cell
# * If you want help on a function, type a question mark `?` after the function to get more documentation

# %% [markdown]
# ## What is Keras?
#
# * Keras is a Python library for deep learning
# * Under the hood, it uses Tensorflow
# * Keras is more user friendly
# * Extensive documentation is here: https://keras.io/

# %% [markdown]
# ## Concepts in this Notebook
#
# 1. Loading and viewing data
#
# 2. Splitting data into training and testing sets
#
# 3. Layers: Convolutional, Fully Connected, Max Pooling
#
# 4. Optimizers
#
# 5. Loss functions
#
# 6. Fitting the model and viewing results

# %% [markdown]
# ## Goal for this Tutorial
#
# Our goal in this tutorial is to predict whether an image has an Anterior-Posterior flip. In large data collection studies, sometimes that coordinate space of images gets flipped, and we want to be able to quickly detect this inconsistency:
#
# ![](https://github.com/akeshavan/IntroDL/blob/master/exampleClassification.png?raw=1)
#
# We will use Python and Keras to do the following:
#
# 1. [Load data](#1.-Loading-Data) from [IXI dataset](http://brain-development.org/ixi-dataset/)
# 2. [Visualize](#2.-Viewing-Data) the slices from our dataset
# 3. [Splitting Data](#3.-Split-data-into-a-training-and-testing-set) into a training and testing set
# 3. [Create Anterior-Posterior flipped data](#4.-Introducing-an-Anterior-Posterior-Flip) so that we can train our model to detect this
# 4. [Create the outcome variable](#5.-Creating-the-outcome-variable): this is what our model will predict
# 5. **[Build a model](#6.-Creating-a-Sequential-Model): Convolutional layers, max pooling, fully connected layers**
# 6. **[Fit our model](#7.-Fitting-the-Model): Epochs, batch size**
# 7. **[Evaluate our model](#8.-Evaluating-the-model): Where did the model go wrong?**
# 8. [Conclusion](#9.-Conclusion)

# %% [markdown]
# # 1. Loading Data

# %% [markdown]
# #### Unzip the data, if you're on colaboratory

# %%
# if you're on collaboratory, UNCOMMENT THE LINES BELOW and then run 

# !mkdir sample_data
# !wget https://s3-ap-southeast-1.amazonaws.com/ohbm2018/sample_data/IXI_small.zip
# !unzip IXI_small.zip -d sample_data/
# Out:
# mkdir: cannot create directory ‘sample_data’: File exists
# --2019-07-08 03:39:02--  https://s3-ap-southeast-1.amazonaws.com/ohbm2018/sample_data/IXI_small.zip
# Resolving s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)... 52.219.40.174
# Connecting to s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)|52.219.40.174|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6103838 (5.8M) [application/zip]
# Saving to: ‘IXI_small.zip’
#
# IXI_small.zip       100%[===================>]   5.82M  2.46MB/s    in 2.4s
#
# 2019-07-08 03:39:06 (2.46 MB/s) - ‘IXI_small.zip’ saved [6103838/6103838]
#
# Archive:  IXI_small.zip
#   inflating: sample_data/F_0.jpg
#   inflating: sample_data/F_1.jpg
#   inflating: sample_data/F_10.jpg
#   inflating: sample_data/F_100.jpg
#   inflating: sample_data/F_101.jpg
#   inflating: sample_data/F_102.jpg
#   inflating: sample_data/F_103.jpg
#   inflating: sample_data/F_104.jpg
#  extracting: sample_data/F_105.jpg
#  extracting: sample_data/F_106.jpg
#   inflating: sample_data/F_107.jpg
#   inflating: sample_data/F_108.jpg
#   inflating: sample_data/F_109.jpg
#   inflating: sample_data/F_11.jpg
#   inflating: sample_data/F_110.jpg
#   inflating: sample_data/F_111.jpg
#   inflating: sample_data/F_112.jpg
#   inflating: sample_data/F_113.jpg
#   inflating: sample_data/F_114.jpg
#   inflating: sample_data/F_115.jpg
#   inflating: sample_data/F_116.jpg
#   inflating: sample_data/F_117.jpg
#   inflating: sample_data/F_118.jpg
#   inflating: sample_data/F_119.jpg
#   inflating: sample_data/F_12.jpg
#   inflating: sample_data/F_120.jpg
#   inflating: sample_data/F_121.jpg
#   inflating: sample_data/F_122.jpg
#   inflating: sample_data/F_123.jpg
#   inflating: sample_data/F_124.jpg
#   inflating: sample_data/F_125.jpg
#   inflating: sample_data/F_126.jpg
#   inflating: sample_data/F_127.jpg
#   inflating: sample_data/F_128.jpg
#   inflating: sample_data/F_129.jpg
#   inflating: sample_data/F_13.jpg
#   inflating: sample_data/F_130.jpg
#   inflating: sample_data/F_131.jpg
#   inflating: sample_data/F_132.jpg
#   inflating: sample_data/F_133.jpg
#   inflating: sample_data/F_134.jpg
#   inflating: sample_data/F_135.jpg
#   inflating: sample_data/F_136.jpg
#   inflating: sample_data/F_137.jpg
#   inflating: sample_data/F_138.jpg
#   inflating: sample_data/F_139.jpg
#   inflating: sample_data/F_14.jpg
#   inflating: sample_data/F_140.jpg
#   inflating: sample_data/F_141.jpg
#   inflating: sample_data/F_142.jpg
#   inflating: sample_data/F_143.jpg
#   inflating: sample_data/F_144.jpg
#   inflating: sample_data/F_145.jpg
#   inflating: sample_data/F_146.jpg
#   inflating: sample_data/F_147.jpg
#   inflating: sample_data/F_148.jpg
#   inflating: sample_data/F_149.jpg
#   inflating: sample_data/F_15.jpg
#   inflating: sample_data/F_150.jpg
#   inflating: sample_data/F_151.jpg
#   inflating: sample_data/F_152.jpg
#   inflating: sample_data/F_153.jpg
#   inflating: sample_data/F_154.jpg
#   inflating: sample_data/F_155.jpg
#   inflating: sample_data/F_156.jpg
#   inflating: sample_data/F_157.jpg
#   inflating: sample_data/F_158.jpg
#   inflating: sample_data/F_159.jpg
#   inflating: sample_data/F_16.jpg
#   inflating: sample_data/F_160.jpg
#   inflating: sample_data/F_161.jpg
#   inflating: sample_data/F_162.jpg
#   inflating: sample_data/F_163.jpg
#   inflating: sample_data/F_164.jpg
#   inflating: sample_data/F_165.jpg
#   inflating: sample_data/F_166.jpg
#   inflating: sample_data/F_167.jpg
#   inflating: sample_data/F_168.jpg
#   inflating: sample_data/F_169.jpg
#   inflating: sample_data/F_17.jpg
#   inflating: sample_data/F_170.jpg
#   inflating: sample_data/F_171.jpg
#   inflating: sample_data/F_172.jpg
#   inflating: sample_data/F_173.jpg
#   inflating: sample_data/F_174.jpg
#   inflating: sample_data/F_175.jpg
#   inflating: sample_data/F_176.jpg
#   inflating: sample_data/F_177.jpg
#   inflating: sample_data/F_178.jpg
#   inflating: sample_data/F_179.jpg
#   inflating: sample_data/F_18.jpg
#   inflating: sample_data/F_180.jpg
#   inflating: sample_data/F_181.jpg
#   inflating: sample_data/F_182.jpg
#   inflating: sample_data/F_183.jpg
#  extracting: sample_data/F_184.jpg
#   inflating: sample_data/F_185.jpg
#   inflating: sample_data/F_186.jpg
#   inflating: sample_data/F_187.jpg
#   inflating: sample_data/F_188.jpg
#   inflating: sample_data/F_189.jpg
#   inflating: sample_data/F_19.jpg
#   inflating: sample_data/F_190.jpg
#   inflating: sample_data/F_191.jpg
#   inflating: sample_data/F_192.jpg
#   inflating: sample_data/F_193.jpg
#   inflating: sample_data/F_194.jpg
#   inflating: sample_data/F_195.jpg
#   inflating: sample_data/F_196.jpg
#   inflating: sample_data/F_197.jpg
#   inflating: sample_data/F_198.jpg
#   inflating: sample_data/F_199.jpg
#   inflating: sample_data/F_2.jpg
#   inflating: sample_data/F_20.jpg
#   inflating: sample_data/F_200.jpg
#   inflating: sample_data/F_201.jpg
#   inflating: sample_data/F_202.jpg
#   inflating: sample_data/F_203.jpg
#   inflating: sample_data/F_204.jpg
#   inflating: sample_data/F_205.jpg
#   inflating: sample_data/F_206.jpg
#   inflating: sample_data/F_207.jpg
#   inflating: sample_data/F_208.jpg
#   inflating: sample_data/F_209.jpg
#   inflating: sample_data/F_21.jpg
#   inflating: sample_data/F_210.jpg
#   inflating: sample_data/F_211.jpg
#   inflating: sample_data/F_212.jpg
#   inflating: sample_data/F_213.jpg
#   inflating: sample_data/F_214.jpg
#   inflating: sample_data/F_215.jpg
#   inflating: sample_data/F_216.jpg
#   inflating: sample_data/F_217.jpg
#   inflating: sample_data/F_218.jpg
#   inflating: sample_data/F_219.jpg
#   inflating: sample_data/F_22.jpg
#   inflating: sample_data/F_220.jpg
#   inflating: sample_data/F_221.jpg
#   inflating: sample_data/F_222.jpg
#   inflating: sample_data/F_223.jpg
#   inflating: sample_data/F_224.jpg
#   inflating: sample_data/F_225.jpg
#   inflating: sample_data/F_226.jpg
#   inflating: sample_data/F_227.jpg
#   inflating: sample_data/F_228.jpg
#   inflating: sample_data/F_229.jpg
#   inflating: sample_data/F_23.jpg
#   inflating: sample_data/F_230.jpg
#   inflating: sample_data/F_231.jpg
#   inflating: sample_data/F_232.jpg
#   inflating: sample_data/F_233.jpg
#   inflating: sample_data/F_234.jpg
#   inflating: sample_data/F_235.jpg
#   inflating: sample_data/F_236.jpg
#   inflating: sample_data/F_237.jpg
#   inflating: sample_data/F_238.jpg
#   inflating: sample_data/F_239.jpg
#   inflating: sample_data/F_24.jpg
#   inflating: sample_data/F_240.jpg
#   inflating: sample_data/F_241.jpg
#   inflating: sample_data/F_242.jpg
#   inflating: sample_data/F_243.jpg
#   inflating: sample_data/F_244.jpg
#   inflating: sample_data/F_245.jpg
#  extracting: sample_data/F_246.jpg
#  extracting: sample_data/F_247.jpg
#   inflating: sample_data/F_248.jpg
#   inflating: sample_data/F_249.jpg
#   inflating: sample_data/F_25.jpg
#   inflating: sample_data/F_250.jpg
#   inflating: sample_data/F_251.jpg
#  extracting: sample_data/F_252.jpg
#   inflating: sample_data/F_253.jpg
#   inflating: sample_data/F_254.jpg
#   inflating: sample_data/F_255.jpg
#   inflating: sample_data/F_256.jpg
#   inflating: sample_data/F_257.jpg
#   inflating: sample_data/F_258.jpg
#   inflating: sample_data/F_259.jpg
#   inflating: sample_data/F_26.jpg
#   inflating: sample_data/F_260.jpg
#   inflating: sample_data/F_261.jpg
#   inflating: sample_data/F_262.jpg
#   inflating: sample_data/F_263.jpg
#   inflating: sample_data/F_264.jpg
#   inflating: sample_data/F_265.jpg
#   inflating: sample_data/F_266.jpg
#   inflating: sample_data/F_267.jpg
#   inflating: sample_data/F_268.jpg
#   inflating: sample_data/F_269.jpg
#   inflating: sample_data/F_27.jpg
#   inflating: sample_data/F_270.jpg
#   inflating: sample_data/F_271.jpg
#   inflating: sample_data/F_272.jpg
#   inflating: sample_data/F_273.jpg
#   inflating: sample_data/F_274.jpg
#   inflating: sample_data/F_275.jpg
#   inflating: sample_data/F_276.jpg
#   inflating: sample_data/F_277.jpg
#   inflating: sample_data/F_278.jpg
#   inflating: sample_data/F_279.jpg
#   inflating: sample_data/F_28.jpg
#   inflating: sample_data/F_280.jpg
#   inflating: sample_data/F_281.jpg
#   inflating: sample_data/F_282.jpg
#   inflating: sample_data/F_283.jpg
#   inflating: sample_data/F_284.jpg
#   inflating: sample_data/F_285.jpg
#   inflating: sample_data/F_286.jpg
#   inflating: sample_data/F_287.jpg
#   inflating: sample_data/F_288.jpg
#   inflating: sample_data/F_289.jpg
#   inflating: sample_data/F_29.jpg
#   inflating: sample_data/F_290.jpg
#   inflating: sample_data/F_291.jpg
#   inflating: sample_data/F_292.jpg
#   inflating: sample_data/F_293.jpg
#   inflating: sample_data/F_294.jpg
#   inflating: sample_data/F_295.jpg
#   inflating: sample_data/F_296.jpg
#   inflating: sample_data/F_297.jpg
#   inflating: sample_data/F_298.jpg
#   inflating: sample_data/F_299.jpg
#  extracting: sample_data/F_3.jpg
#   inflating: sample_data/F_30.jpg
#   inflating: sample_data/F_300.jpg
#   inflating: sample_data/F_301.jpg
#   inflating: sample_data/F_302.jpg
#   inflating: sample_data/F_303.jpg
#   inflating: sample_data/F_304.jpg
#   inflating: sample_data/F_305.jpg
#   inflating: sample_data/F_306.jpg
#   inflating: sample_data/F_307.jpg
#   inflating: sample_data/F_308.jpg
#   inflating: sample_data/F_309.jpg
#   inflating: sample_data/F_31.jpg
#   inflating: sample_data/F_310.jpg
#   inflating: sample_data/F_311.jpg
#   inflating: sample_data/F_312.jpg
#   inflating: sample_data/F_313.jpg
#   inflating: sample_data/F_314.jpg
#   inflating: sample_data/F_315.jpg
#   inflating: sample_data/F_316.jpg
#   inflating: sample_data/F_317.jpg
#   inflating: sample_data/F_318.jpg
#   inflating: sample_data/F_319.jpg
#   inflating: sample_data/F_32.jpg
#  extracting: sample_data/F_320.jpg
#   inflating: sample_data/F_321.jpg
#   inflating: sample_data/F_322.jpg
#   inflating: sample_data/F_323.jpg
#   inflating: sample_data/F_324.jpg
#   inflating: sample_data/F_325.jpg
#   inflating: sample_data/F_326.jpg
#   inflating: sample_data/F_33.jpg
#  extracting: sample_data/F_34.jpg
#   inflating: sample_data/F_35.jpg
#   inflating: sample_data/F_36.jpg
#   inflating: sample_data/F_37.jpg
#   inflating: sample_data/F_38.jpg
#   inflating: sample_data/F_39.jpg
#   inflating: sample_data/F_4.jpg
#   inflating: sample_data/F_40.jpg
#   inflating: sample_data/F_41.jpg
#   inflating: sample_data/F_42.jpg
#   inflating: sample_data/F_43.jpg
#   inflating: sample_data/F_44.jpg
#   inflating: sample_data/F_45.jpg
#   inflating: sample_data/F_46.jpg
#   inflating: sample_data/F_47.jpg
#   inflating: sample_data/F_48.jpg
#   inflating: sample_data/F_49.jpg
#   inflating: sample_data/F_5.jpg
#   inflating: sample_data/F_50.jpg
#   inflating: sample_data/F_51.jpg
#   inflating: sample_data/F_52.jpg
#   inflating: sample_data/F_53.jpg
#   inflating: sample_data/F_54.jpg
#   inflating: sample_data/F_55.jpg
#   inflating: sample_data/F_56.jpg
#   inflating: sample_data/F_57.jpg
#   inflating: sample_data/F_58.jpg
#   inflating: sample_data/F_59.jpg
#   inflating: sample_data/F_6.jpg
#   inflating: sample_data/F_60.jpg
#   inflating: sample_data/F_61.jpg
#   inflating: sample_data/F_62.jpg
#   inflating: sample_data/F_63.jpg
#   inflating: sample_data/F_64.jpg
#   inflating: sample_data/F_65.jpg
#   inflating: sample_data/F_66.jpg
#  extracting: sample_data/F_67.jpg
#   inflating: sample_data/F_68.jpg
#   inflating: sample_data/F_69.jpg
#   inflating: sample_data/F_7.jpg
#   inflating: sample_data/F_70.jpg
#   inflating: sample_data/F_71.jpg
#   inflating: sample_data/F_72.jpg
#   inflating: sample_data/F_73.jpg
#   inflating: sample_data/F_74.jpg
#   inflating: sample_data/F_75.jpg
#   inflating: sample_data/F_76.jpg
#   inflating: sample_data/F_77.jpg
#   inflating: sample_data/F_78.jpg
#   inflating: sample_data/F_79.jpg
#   inflating: sample_data/F_8.jpg
#   inflating: sample_data/F_80.jpg
#   inflating: sample_data/F_81.jpg
#   inflating: sample_data/F_82.jpg
#   inflating: sample_data/F_83.jpg
#   inflating: sample_data/F_84.jpg
#   inflating: sample_data/F_85.jpg
#   inflating: sample_data/F_86.jpg
#   inflating: sample_data/F_87.jpg
#   inflating: sample_data/F_88.jpg
#   inflating: sample_data/F_89.jpg
#   inflating: sample_data/F_9.jpg
#   inflating: sample_data/F_90.jpg
#   inflating: sample_data/F_91.jpg
#   inflating: sample_data/F_92.jpg
#   inflating: sample_data/F_93.jpg
#   inflating: sample_data/F_94.jpg
#   inflating: sample_data/F_95.jpg
#   inflating: sample_data/F_96.jpg
#   inflating: sample_data/F_97.jpg
#   inflating: sample_data/F_98.jpg
#   inflating: sample_data/F_99.jpg
#   inflating: sample_data/M_0.jpg
#   inflating: sample_data/M_1.jpg
#   inflating: sample_data/M_10.jpg
#   inflating: sample_data/M_100.jpg
#  extracting: sample_data/M_101.jpg
#   inflating: sample_data/M_102.jpg
#   inflating: sample_data/M_103.jpg
#   inflating: sample_data/M_104.jpg
#   inflating: sample_data/M_105.jpg
#   inflating: sample_data/M_106.jpg
#   inflating: sample_data/M_107.jpg
#   inflating: sample_data/M_108.jpg
#   inflating: sample_data/M_109.jpg
#   inflating: sample_data/M_11.jpg
#   inflating: sample_data/M_110.jpg
#   inflating: sample_data/M_111.jpg
#   inflating: sample_data/M_112.jpg
#   inflating: sample_data/M_113.jpg
#   inflating: sample_data/M_114.jpg
#   inflating: sample_data/M_115.jpg
#   inflating: sample_data/M_116.jpg
#   inflating: sample_data/M_117.jpg
#   inflating: sample_data/M_118.jpg
#   inflating: sample_data/M_119.jpg
#   inflating: sample_data/M_12.jpg
#   inflating: sample_data/M_120.jpg
#   inflating: sample_data/M_121.jpg
#   inflating: sample_data/M_122.jpg
#   inflating: sample_data/M_123.jpg
#   inflating: sample_data/M_124.jpg
#  extracting: sample_data/M_125.jpg
#   inflating: sample_data/M_126.jpg
#   inflating: sample_data/M_127.jpg
#   inflating: sample_data/M_128.jpg
#   inflating: sample_data/M_129.jpg
#   inflating: sample_data/M_13.jpg
#   inflating: sample_data/M_130.jpg
#   inflating: sample_data/M_131.jpg
#   inflating: sample_data/M_132.jpg
#   inflating: sample_data/M_133.jpg
#   inflating: sample_data/M_134.jpg
#   inflating: sample_data/M_135.jpg
#   inflating: sample_data/M_136.jpg
#   inflating: sample_data/M_137.jpg
#   inflating: sample_data/M_138.jpg
#   inflating: sample_data/M_139.jpg
#   inflating: sample_data/M_14.jpg
#   inflating: sample_data/M_140.jpg
#   inflating: sample_data/M_141.jpg
#  extracting: sample_data/M_142.jpg
#   inflating: sample_data/M_143.jpg
#   inflating: sample_data/M_144.jpg
#   inflating: sample_data/M_145.jpg
#  extracting: sample_data/M_146.jpg
#   inflating: sample_data/M_147.jpg
#   inflating: sample_data/M_148.jpg
#   inflating: sample_data/M_149.jpg
#   inflating: sample_data/M_15.jpg
#  extracting: sample_data/M_150.jpg
#   inflating: sample_data/M_151.jpg
#   inflating: sample_data/M_152.jpg
#   inflating: sample_data/M_153.jpg
#   inflating: sample_data/M_154.jpg
#   inflating: sample_data/M_155.jpg
#   inflating: sample_data/M_156.jpg
#   inflating: sample_data/M_157.jpg
#   inflating: sample_data/M_158.jpg
#   inflating: sample_data/M_159.jpg
#   inflating: sample_data/M_16.jpg
#   inflating: sample_data/M_160.jpg
#   inflating: sample_data/M_161.jpg
#   inflating: sample_data/M_162.jpg
#   inflating: sample_data/M_163.jpg
#   inflating: sample_data/M_164.jpg
#   inflating: sample_data/M_165.jpg
#   inflating: sample_data/M_166.jpg
#   inflating: sample_data/M_167.jpg
#   inflating: sample_data/M_168.jpg
#  extracting: sample_data/M_169.jpg
#   inflating: sample_data/M_17.jpg
#   inflating: sample_data/M_170.jpg
#   inflating: sample_data/M_171.jpg
#   inflating: sample_data/M_172.jpg
#   inflating: sample_data/M_173.jpg
#   inflating: sample_data/M_174.jpg
#   inflating: sample_data/M_175.jpg
#   inflating: sample_data/M_176.jpg
#   inflating: sample_data/M_177.jpg
#   inflating: sample_data/M_178.jpg
#   inflating: sample_data/M_179.jpg
#  extracting: sample_data/M_18.jpg
#   inflating: sample_data/M_180.jpg
#   inflating: sample_data/M_181.jpg
#   inflating: sample_data/M_182.jpg
#   inflating: sample_data/M_183.jpg
#   inflating: sample_data/M_184.jpg
#   inflating: sample_data/M_185.jpg
#   inflating: sample_data/M_186.jpg
#   inflating: sample_data/M_187.jpg
#   inflating: sample_data/M_188.jpg
#   inflating: sample_data/M_189.jpg
#   inflating: sample_data/M_19.jpg
#   inflating: sample_data/M_190.jpg
#   inflating: sample_data/M_191.jpg
#   inflating: sample_data/M_192.jpg
#   inflating: sample_data/M_193.jpg
#   inflating: sample_data/M_194.jpg
#   inflating: sample_data/M_195.jpg
#   inflating: sample_data/M_196.jpg
#  extracting: sample_data/M_197.jpg
#  extracting: sample_data/M_198.jpg
#   inflating: sample_data/M_199.jpg
#   inflating: sample_data/M_2.jpg
#   inflating: sample_data/M_20.jpg
#   inflating: sample_data/M_200.jpg
#  extracting: sample_data/M_201.jpg
#   inflating: sample_data/M_202.jpg
#  extracting: sample_data/M_203.jpg
#   inflating: sample_data/M_204.jpg
#   inflating: sample_data/M_205.jpg
#   inflating: sample_data/M_206.jpg
#   inflating: sample_data/M_207.jpg
#   inflating: sample_data/M_208.jpg
#   inflating: sample_data/M_209.jpg
#  extracting: sample_data/M_21.jpg
#   inflating: sample_data/M_210.jpg
#   inflating: sample_data/M_211.jpg
#   inflating: sample_data/M_212.jpg
#   inflating: sample_data/M_213.jpg
#   inflating: sample_data/M_214.jpg
#   inflating: sample_data/M_215.jpg
#   inflating: sample_data/M_216.jpg
#   inflating: sample_data/M_217.jpg
#   inflating: sample_data/M_218.jpg
#   inflating: sample_data/M_219.jpg
#   inflating: sample_data/M_22.jpg
#   inflating: sample_data/M_220.jpg
#   inflating: sample_data/M_221.jpg
#   inflating: sample_data/M_222.jpg
#   inflating: sample_data/M_223.jpg
#   inflating: sample_data/M_224.jpg
#   inflating: sample_data/M_225.jpg
#   inflating: sample_data/M_226.jpg
#   inflating: sample_data/M_227.jpg
#   inflating: sample_data/M_228.jpg
#   inflating: sample_data/M_229.jpg
#   inflating: sample_data/M_23.jpg
#   inflating: sample_data/M_230.jpg
#   inflating: sample_data/M_231.jpg
#   inflating: sample_data/M_232.jpg
#   inflating: sample_data/M_233.jpg
#   inflating: sample_data/M_234.jpg
#   inflating: sample_data/M_235.jpg
#   inflating: sample_data/M_236.jpg
#   inflating: sample_data/M_237.jpg
#   inflating: sample_data/M_238.jpg
#   inflating: sample_data/M_239.jpg
#   inflating: sample_data/M_24.jpg
#   inflating: sample_data/M_240.jpg
#   inflating: sample_data/M_241.jpg
#   inflating: sample_data/M_242.jpg
#   inflating: sample_data/M_243.jpg
#   inflating: sample_data/M_244.jpg
#   inflating: sample_data/M_245.jpg
#   inflating: sample_data/M_246.jpg
#   inflating: sample_data/M_247.jpg
#   inflating: sample_data/M_248.jpg
#   inflating: sample_data/M_249.jpg
#  extracting: sample_data/M_25.jpg
#   inflating: sample_data/M_250.jpg
#   inflating: sample_data/M_251.jpg
#   inflating: sample_data/M_252.jpg
#   inflating: sample_data/M_253.jpg
#   inflating: sample_data/M_254.jpg
#   inflating: sample_data/M_255.jpg
#   inflating: sample_data/M_256.jpg
#   inflating: sample_data/M_257.jpg
#   inflating: sample_data/M_258.jpg
#   inflating: sample_data/M_259.jpg
#   inflating: sample_data/M_26.jpg
#   inflating: sample_data/M_260.jpg
#   inflating: sample_data/M_261.jpg
#   inflating: sample_data/M_262.jpg
#   inflating: sample_data/M_27.jpg
#   inflating: sample_data/M_28.jpg
#  extracting: sample_data/M_29.jpg
#  extracting: sample_data/M_3.jpg
#   inflating: sample_data/M_30.jpg
#  extracting: sample_data/M_31.jpg
#   inflating: sample_data/M_32.jpg
#   inflating: sample_data/M_33.jpg
#   inflating: sample_data/M_34.jpg
#   inflating: sample_data/M_35.jpg
#   inflating: sample_data/M_36.jpg
#   inflating: sample_data/M_37.jpg
#  extracting: sample_data/M_38.jpg
#   inflating: sample_data/M_39.jpg
#   inflating: sample_data/M_4.jpg
#   inflating: sample_data/M_40.jpg
#   inflating: sample_data/M_41.jpg
#   inflating: sample_data/M_42.jpg
#   inflating: sample_data/M_43.jpg
#   inflating: sample_data/M_44.jpg
#  extracting: sample_data/M_45.jpg
#   inflating: sample_data/M_46.jpg
#   inflating: sample_data/M_47.jpg
#   inflating: sample_data/M_48.jpg
#   inflating: sample_data/M_49.jpg
#   inflating: sample_data/M_5.jpg
#   inflating: sample_data/M_50.jpg
#   inflating: sample_data/M_51.jpg
#   inflating: sample_data/M_52.jpg
#  extracting: sample_data/M_53.jpg
#   inflating: sample_data/M_54.jpg
#   inflating: sample_data/M_55.jpg
#  extracting: sample_data/M_56.jpg
#   inflating: sample_data/M_57.jpg
#   inflating: sample_data/M_58.jpg
#   inflating: sample_data/M_59.jpg
#   inflating: sample_data/M_6.jpg
#   inflating: sample_data/M_60.jpg
#   inflating: sample_data/M_61.jpg
#   inflating: sample_data/M_62.jpg
#   inflating: sample_data/M_63.jpg
#  extracting: sample_data/M_64.jpg
#   inflating: sample_data/M_65.jpg
#   inflating: sample_data/M_66.jpg
#   inflating: sample_data/M_67.jpg
#   inflating: sample_data/M_68.jpg
#   inflating: sample_data/M_69.jpg
#  extracting: sample_data/M_7.jpg
#   inflating: sample_data/M_70.jpg
#   inflating: sample_data/M_71.jpg
#   inflating: sample_data/M_72.jpg
#   inflating: sample_data/M_73.jpg
#   inflating: sample_data/M_74.jpg
#   inflating: sample_data/M_75.jpg
#   inflating: sample_data/M_76.jpg
#   inflating: sample_data/M_77.jpg
#   inflating: sample_data/M_78.jpg
#   inflating: sample_data/M_79.jpg
#   inflating: sample_data/M_8.jpg
#   inflating: sample_data/M_80.jpg
#   inflating: sample_data/M_81.jpg
#   inflating: sample_data/M_82.jpg
#   inflating: sample_data/M_83.jpg
#   inflating: sample_data/M_84.jpg
#   inflating: sample_data/M_85.jpg
#   inflating: sample_data/M_86.jpg
#   inflating: sample_data/M_87.jpg
#  extracting: sample_data/M_88.jpg
#   inflating: sample_data/M_89.jpg
#   inflating: sample_data/M_9.jpg
#   inflating: sample_data/M_90.jpg
#   inflating: sample_data/M_91.jpg
#   inflating: sample_data/M_92.jpg
#   inflating: sample_data/M_93.jpg
#   inflating: sample_data/M_94.jpg
#   inflating: sample_data/M_95.jpg
#   inflating: sample_data/M_96.jpg
#   inflating: sample_data/M_97.jpg
#   inflating: sample_data/M_98.jpg
#   inflating: sample_data/M_99.jpg

# %% [markdown]
# #### Count the number of jpg files we have
#
# The `glob` function in python will return a list of files that match our pattern

# %%
from glob import glob

image_files = glob('sample_data/*.jpg')
N = len(image_files)
print(N)
# Out:
# 590

# %% [markdown]
# #### Import python libraries

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load JPG images into a numpy array

# %%
def load_image(filename):
    data_slice = plt.imread(filename)
    assert data_slice.shape == (256,256), "image file is not the right shape"
    return data_slice

# %%
# initialize an array that is the shape we need:

data_array = np.zeros((N, 256, 256, 1)) 
# the last dimension is the number of channels in the image.
# a grayscale image has 1 channel, while an RGB image has 3 channels (R,G,B).
# Could be MR modalities (channel1 = T1, channel2 = T2)

# iterate through all of the image files
for i, file in enumerate(image_files):
    # in Python, enumerate is a special function that gives us 
    # an index (i) and the item in the list (file)
    
    
    # load the file using our function
    data_slice = load_image(file)
    
    # put the data into our array, X
    data_array[i, :, :, 0] = data_slice

# %% [markdown]
# # 2. Viewing Data
#
# Visualizing your data is important! Now that our data is in a 4D array, we will visualize a single slice:

# %%
def view_slice(data, index):
    plt.imshow(data[index,:,:,0],cmap=plt.cm.Greys_r)
    plt.axis('off');

# %% [markdown]
# View the first slice in our array (index=0)

# %%
view_slice(data_array, 0)

# %%
view_slice(data_array, 200)

# %% [markdown]
# # 3. Split data into a training and testing set
#
# Its *really* important to do this. We need to make sure our model can generalize to new, unseen data. Here, we randomly shuffle our data, and reserve 80% of it for our training data, and the remaining 20% for testing.

# %%
np.random.seed(0) # set the random number generator seed, for consistency

indices = np.arange(N) # returns a 1D array, [0,1,...N-1]
np.random.shuffle(indices) # shuffles the indicies

# the first 80% of the data will be the training set.
N_80p = int(0.8 * N)
indices_train = indices[:N_80p]
X_train = data_array[indices_train,:,:,:]

# the last 20% of the data will be the testing set.

indices_test = indices[N_80p:]
X_test = data_array[indices_test,:,:,:]

print(X_train.shape, X_test.shape)
# Out:
# (472, 256, 256, 1) (118, 256, 256, 1)

# %% [markdown]
# # 4. Introducing an Anterior-Posterior Flip
#
# Right now our training data has all the saggital slices pointing to the left. We want our model to detect orientation anomalies (e.g. if the orientation has flipped in the anterior-poster direction ). To do this, we generate another array of data that is purposely flipped.
#
# Indexing a python array with `::-1` reverses the order of the data. The third axis of our 4D array is the x-axis ordering, so we need to reverse the index there:

# %%
X_train_flip = X_train[:, :, ::-1, :]
X_test_flip = X_test[:, :, ::-1, :]

# %% [markdown]
# Lets make sure we did this right:

# %%
view_slice(X_train_flip, 100)

# %% [markdown]
# That looks good!
#
# #### Combine X and X_flip into 1 array
#
# Now we will combine the original `X_train` and the flipped `X_train_flipped` into 1 array. And do the same with the test set

# %%
X_train = np.vstack((X_train, X_train_flip))
X_test = np.vstack((X_test, X_test_flip))

# %%
X_train.shape
# Out:
# (944, 256, 256, 1)

# %%
X_test.shape
# Out:
# (236, 256, 256, 1)

# %% [markdown]
# # 5. Creating the outcome variable

# %% [markdown]
# We need to define a variable that holds the outcome variable (1 or 0) that indicates whether or not the image is flipped. We know the first half of the X array corresponds to images that are the correct orientation, and the second half are not.
#
# The steps we take here are:
#
# 1. Initialize an array of 0s that is the same length as X_train
# 2. Set the first half to 1

# %%
y_train_label = np.zeros(X_train.shape[0])

N_train_half = int(X_train.shape[0] / 2)
y_train_label[:N_train_half] = 1


y_test_label = np.zeros(X_test.shape[0])

N_test_half = int(X_test.shape[0] / 2)
y_test_label[:N_test_half] = 1

# %% [markdown]
# We need to reformat the shape of our outcome variables, `y_train` and `y_test`, because Keras needs the labels as a 2D array. Keras provides a function to do this:

# %%
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
y_train = to_categorical(y_train_label)
y_test = to_categorical(y_test_label)

# %%
y_train
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %% [markdown]
# Shuffle the training data so that the samples aren't grouped

# %%
shuffled_train_indices = np.arange(2*N_train_half)
np.random.shuffle(shuffled_train_indices)

X_train = X_train[shuffled_train_indices, :,:,:]
y_train = y_train[shuffled_train_indices, :]

# %%
print(X_train.shape, y_train.shape)
# Out:
# (944, 256, 256, 1) (944, 2)

# %%
y_train
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]], dtype=float32)

# %% [markdown]
# # 6. Creating a Sequential Model

# %% [markdown]
# import the necessary functions from the Keras library

# %%
import tensorflow as tf
from keras.models import Sequential

from keras.layers import Dense, Flatten, Dropout
from keras.layers import Conv2D, BatchNormalization, MaxPooling2D

from keras.optimizers import Adam, SGD

from keras import backend as K
K.clear_session()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0708 03:45:06.925415 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0708 03:45:06.929057 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0708 03:45:06.979506 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
kernel_size = (3, 3)
n_classes = 2

filters = 8

model = Sequential() ### can create others

model.add(Conv2D(filters, kernel_size, activation='relu', 
                 input_shape=(256, 256, 1)))
# zero mean unit variance
model.add(BatchNormalization())

model.add(MaxPooling2D()) # max pooling
model.add(Conv2D(filters*2, kernel_size, activation='relu')) # convolution

model.add(MaxPooling2D())
model.add(Conv2D(filters*4, kernel_size, activation='relu'))

model.add(MaxPooling2D())
model.add(Conv2D(filters*8, kernel_size, activation='relu'))

model.add(MaxPooling2D())
model.add(Conv2D(filters*16, kernel_size, activation='relu'))

model.add(MaxPooling2D())
model.add(Conv2D(filters*32, kernel_size, activation='relu'))

model.add(MaxPooling2D())
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(n_classes, activation='softmax'))

learning_rate = 1e-5
# optimizer
adam = Adam(lr=learning_rate)
sgd = SGD(lr=learning_rate)


model.compile(loss='categorical_crossentropy',
                 optimizer=adam, # swap out for sgd 
                 metrics=['accuracy'])

model.summary() ### shapes of layers
# Out:
# W0708 03:46:56.975893 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0708 03:46:56.981221 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0708 03:47:00.117835 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0708 03:47:00.276772 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0708 03:47:00.387379 139823251564416 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0708 03:47:00.483830 139823251564416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 8)       80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 254, 254, 8)       32
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 541,410
# Trainable params: 541,394
# Non-trainable params: 16
# _________________________________________________________________

# %% [markdown]
# # 7. Fitting the Model

# %%
fit = model.fit(X_train, y_train, epochs=5, batch_size=2)
# Out:
# W0708 03:47:59.756248 139823251564416 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5
# 944/944 [==============================] - 11s 12ms/step - loss: 0.6998 - acc: 0.5551
# Epoch 2/5
# 944/944 [==============================] - 7s 8ms/step - loss: 0.5807 - acc: 0.7119
# Epoch 3/5
# 944/944 [==============================] - 7s 8ms/step - loss: 0.3979 - acc: 0.8792
# Epoch 4/5
# 944/944 [==============================] - 7s 8ms/step - loss: 0.2076 - acc: 0.9587
# Epoch 5/5
# 944/944 [==============================] - 7s 8ms/step - loss: 0.0962 - acc: 0.9841

# %%
def get_figure():
    """
    Returns figure and axis objects to plot on. 
    Removes top and right border and ticks, because those are ugly
    """
    fig, ax = plt.subplots(1)
    plt.tick_params(top='off', right='off', which='both') 
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    return fig, ax

# %%
fig, ax = get_figure()

epoch = np.arange(5) + 1
ax.plot(epoch, fit.history['acc'], marker="o", linewidth=2, color="steelblue", label="accuracy")
ax.plot(epoch, fit.history['loss'], marker="o", linewidth=2, color="orange", label="loss")
ax.set_xlabel('epoch')
ax.legend(frameon=False);

# %% [markdown]
# # 8. Evaluating the model

# %%
model.evaluate(X_test, y_test)
# Out:
# 236/236 [==============================] - 3s 14ms/step
# [0.02672418983558477, 0.9957627118644068]

# %% [markdown]
# #### What did it mess up on?

# %%
y_pred = model.predict(X_test)

# %%
fig, ax = get_figure()
ax.hist(y_pred[:,0], color="steelblue");

# %%
np.nonzero(np.isclose(y_test[:,0], y_pred[:,0], atol=4e-1) == False)
# Out:
# (array([ 47, 165]),)

# %%
view_slice(X_test, 47)

# %%
view_slice(X_test, 165)

# %% [markdown]
# #### What about the training set?

# %%
y_train_pred = model.predict(X_train)

# %%
fig, ax = get_figure()
ax.hist(y_train_pred[:,0], color="steelblue");

# %%
np.nonzero(np.isclose(y_train[:,0], y_train_pred[:,0], atol=2e-1) == False)
# Out:
# (array([ 21, 487, 608, 641, 661, 786, 828]),)

# %%
view_slice(X_train, 641)

# %%
view_slice(X_train, 661)

# %%
view_slice(X_train, 828)

# %% [markdown]
# # 9. Conclusion

# %% [markdown]
# ### Data Input
#
# * We loaded 2D JPG images --> numpy array. You can use the `nibabel` library to load nifti images (you'd need a GPU)
# * We created 2 classes of images that were perfectly balanced: one oriented "correctly" and the other oriented "incorrectly". You can try to train a model to predict age or sex from the [IXI dataset demographics spreadsheet](http://biomedic.doc.ic.ac.uk/brain-development/downloads/IXI/IXI.xls)
# * Our dependent variable `y_train`, `y_test` was a binary label, but we converted it to a 2D array
#
#
# ### Training and Testing
# * it is not wise to train on your entire dataset, because you will overfit.
# * ALWAYS split your data
#
#
# ### Model Creation
# * We used a `Sequential` model, but you can also use the more generic [Model class](https://keras.io/getting-started/functional-api-guide/)
# * `model.summary()` is very useful
# * try fiddling with learning rate and optimizers (Adam, SGD) -- what happens?
# * try adding or removing layers -- what happens?
#
# ### Output
# * `model.evaluate` returns the loss, accuracy of your model
# * `model.predict` returns an array with the predicted values
#
# ### Documentation
#
# * There is excellent documentation online! Check out https://keras.io to get started

# %% [markdown]
# # 10. Extra: Visualizing Activations
#
# Visualizing intermediate outputs of the network

# %%
layer_dict = dict([(layer.name, layer) for layer in model.layers])

def show_activation(layer_name):
    
    layer_output = layer_dict[layer_name].output

    fn = K.function([model.input], [layer_output])
    
    inp = X_train[0:1]
    
    this_hidden = fn([inp])[0]
    
    # plot the activations from the first 8 filters
    plt.figure(figsize=(15,8))
    for i in range(8):
        plt.subplot(1,8,i+1)
        plt.imshow(this_hidden[0,:,:,i], plt.cm.Greys_r)
        plt.axis('off')
    
    return

# %%
show_activation('conv2d_1')

# %%
show_activation('conv2d_2')

# %%
show_activation('conv2d_3')

# %%
show_activation('conv2d_4')

# %%
show_activation('conv2d_5')

# %%
show_activation('conv2d_6')
